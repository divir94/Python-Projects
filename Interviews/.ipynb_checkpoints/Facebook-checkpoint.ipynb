# %%
// You are given K lists that are already sorted, and the total number of elements in all the lists is N.
// Write an algorithm that merges these sorted lists into a single sorted list containing all elements of all lists.

// Example:
// merge([[1,4,10], 
         [1,9], 
         [11,15]]) => [1,1,4,9,10,11,15]

k * n

// list A -> length of a
// list B -> length of b
// list C -> length of c

n/k + 0
n/k + n/k
n/k + 2n/k
n/k + 3n/k

(n/k * k) + (1 + 2 + ... + k-1)*n/k
n + (n*n+1)/2 * n/k

n / k
X = merge(A, B) # n / k
Y = merge(X, C) # a + b + c 

def merge(A, B):
    if A == None:
        return B
    if B == None:
        return A
    C = []
    sizeA, sizeB = len(A), len(B) # 1, 2
    i, j = 0, 0
    while (i != sizeA) and (j != sizeB):
        if A[i] <= B[j]:
            C.append(A[i])
            i += 1
        else:
            C.append(B[j])
            j += 1
    C += B[j:] if i == sizeA else A[i:]
    return C

// merge([[1,4,10], 
         [1,9], 
         [11,15,17]]) => [1,1,4,9,10,11,15]

def mergeAll(M):
    C = []
    k = len(M)
    k_idxs = [0] * k
    k_size = [len(M[i]) for i in M] 
    while all_but_one(k_idxs, k_size):
        min_index = -1
        min_val = float("inf")
        for i, k_idx in enumerate(k_idxs):
            if k_idx < k_size[i] and M[i][k_idx] < min_val:
                min_val = M[i][k_idx]
                min_index = i
                k_idxs[i] += 1
        C.append(M[i][k_idxs[i]])
    rem = get_rem(k_idxs, k_size)
    C.append(rem)
    return C

# C = [1, ]
# i = 0
# j = 0
# min_val = 1
# min_idx = 0

M = [[1, 3],
    [2, 4]]

# C = [1, 2, 3]
# i, j = 1, 1

print merge([2], [1, 3])
